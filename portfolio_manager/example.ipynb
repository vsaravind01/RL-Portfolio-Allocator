# %%
from drl_agent import DRLAgent
from env import StockPortfolioEnv
from data_loader import Yahoo_Downloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer
import pandas as pd
from utils import data_split
from pyfolio import timeseries
# Out:
# /Users/vsaravind/dev/rl_final_lab/portfolio_manager/.venv/lib/python3.10/site-packages/pyfolio/pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %%
from settings import MODEL_MAP

# %%
def get_data(tickers, start_date, end_date):
    df = Yahoo_Downloader(ticker_list=tickers, start_date=start_date, end_date=end_date).fetch_data()
    fe = FeatureEngineer(use_technical_indicator=True, use_turbulence=False, user_defined_feature=False)
    df = fe.preprocess_data(df)

    # add covariance matrix as states
    df = df.sort_values(["date", "tic"], ignore_index=True)
    df.index = df.date.factorize()[0]

    cov_list = []
    return_list = []

    # look back is one year
    lookback = 252
    for i in range(lookback, len(df.index.unique())):
        data_lookback = df.loc[i - lookback : i, :]
        price_lookback = data_lookback.pivot_table(index="date", columns="tic", values="close")
        return_lookback = price_lookback.pct_change().dropna()
        return_list.append(return_lookback)

        covs = return_lookback.cov().values
        cov_list.append(covs)

    df_cov = pd.DataFrame(
        {"date": df.date.unique()[lookback:], "cov_list": cov_list, "return_list": return_list}
    )
    df = df.merge(df_cov, on="date")
    df = df.sort_values(["date", "tic"]).reset_index(drop=True)
    df = data_split(df, start_date, end_date)
    return df

# %%
def generate_environment(
    df,
    initial_amount,
    transaction_cost_pct=0,
    tech_indicator_list=["macd", "rsi_30", "cci_30", "dx_30"],
):
    stock_dimension = len(df.tic.unique())
    state_space = stock_dimension
    env_kwargs = {
        "hmax": 100,
        "initial_amount": initial_amount,
        "transaction_cost_pct": transaction_cost_pct,
        "state_space": state_space,
        "stock_dim": stock_dimension,
        "tech_indicator_list": tech_indicator_list,
        "action_space": stock_dimension,
        "reward_scaling": 1e-1,
    }
    e_gym = StockPortfolioEnv(df=df, **env_kwargs)
    return e_gym

# %%
def get_agent(env):
    return DRLAgent(env)

# %%
def get_model(model_name, agent):
    model_params = MODEL_MAP[model_name]
    model = agent.get_model(model_name, model_kwargs = model_params)
    return model

# %%
from settings import DOW_30_TICKER

# %%
df = get_data(tickers=DOW_30_TICKER, start_date="2004-01-01", end_date="2021-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (123395, 8)
# Successfully added technical indicators

# %%
env = generate_environment(df, initial_amount=1000000)

# %%
env_train, _ = env.get_sb_env()
agent = get_agent(env_train)
model = get_model("ppo", agent)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.005, 'learning_rate': 0.001, 'batch_size': 128}
# Using cpu device
# /Users/vsaravind/dev/rl_final_lab/portfolio_manager/.venv/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
trained_ppo = agent.train_model(model=model, tb_log_name="ppo", total_timesteps=40000)
# Out:
# ----------------------------------
# | time/              |           |
# |    fps             | 1233      |
# |    iterations      | 1         |
# |    time_elapsed    | 1         |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 2368749.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:7489155.539859982
# Sharpe:  0.7521440833312614
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1076      |
# |    iterations           | 2         |
# |    time_elapsed         | 3         |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -38.3     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 3.28e+14  |
# |    n_updates            | 10        |
# |    policy_gradient_loss | -8.85e-06 |
# |    reward               | 1000554.3 |
# |    std                  | 1         |
# |    value_loss           | 6.33e+14  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1053      |
# |    iterations           | 3         |
# |    time_elapsed         | 5         |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -38.3     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 2.89e+15  |
# |    n_updates            | 20        |
# |    policy_gradient_loss | -2.54e-06 |
# |    reward               | 2407181.5 |
# |    std                  | 1         |
# |    value_loss           | 6.06e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6953926.993456593
# Sharpe:  0.7270899761962516
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1033      |
# |    iterations           | 4         |
# |    time_elapsed         | 7         |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -38.3     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 3e+14     |
# |    n_updates            | 30        |
# |    policy_gradient_loss | -8.52e-06 |
# |    reward               | 1057577.9 |
# |    std                  | 1         |
# |    value_loss           | 6.13e+14  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1029      |
# |    iterations           | 5         |
# |    time_elapsed         | 9         |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -38.3     |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.001     |
# |    loss                 | 2.44e+15  |
# |    n_updates            | 40        |
# |    policy_gradient_loss | -2.75e-06 |
# |    reward               | 2603438.8 |
# |    std                  | 1         |
# |    value_loss           | 4.89e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:7619538.679649574
# Sharpe:  0.7558760447311527
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1016      |
# |    iterations           | 6         |
# |    time_elapsed         | 12        |
# |    total_timesteps      | 12288     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -38.3     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 3.86e+14  |
# |    n_updates            | 50        |
# |    policy_gradient_loss | -6.84e-06 |
# |    reward               | 1065381.5 |
# |    std                  | 1         |
# |    value_loss           | 7.45e+14  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1013      |
# |    iterations           | 7         |
# |    time_elapsed         | 14        |
# |    total_timesteps      | 14336     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -38.3     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 2.88e+15  |
# |    n_updates            | 60        |
# |    policy_gradient_loss | -2.98e-06 |
# |    reward               | 2797947.0 |
# |    std                  | 1         |
# |    value_loss           | 5.81e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:7515870.256939319
# Sharpe:  0.7514214141650318
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1018      |
# |    iterations           | 8         |
# |    time_elapsed         | 16        |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -38.3     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | 3.84e+14  |
# |    n_updates            | 70        |
# |    policy_gradient_loss | -7.29e-06 |
# |    reward               | 1147567.1 |
# |    std                  | 1         |
# |    value_loss           | 7.86e+14  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1023      |
# |    iterations           | 9         |
# |    time_elapsed         | 18        |
# |    total_timesteps      | 18432     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -38.3     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 3.07e+15  |
# |    n_updates            | 80        |
# |    policy_gradient_loss | -2.96e-06 |
# |    reward               | 3165384.2 |
# |    std                  | 1         |
# |    value_loss           | 5.78e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:7892634.7916946355
# Sharpe:  0.7700707255910416
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1020      |
# |    iterations           | 10        |
# |    time_elapsed         | 20        |
# |    total_timesteps      | 20480     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -38.3     |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.001     |
# |    loss                 | 4.99e+14  |
# |    n_updates            | 90        |
# |    policy_gradient_loss | -6.26e-06 |
# |    reward               | 1155018.6 |
# |    std                  | 1         |
# |    value_loss           | 9.5e+14   |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1025      |
# |    iterations           | 11        |
# |    time_elapsed         | 21        |
# |    total_timesteps      | 22528     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -38.3     |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.001     |
# |    loss                 | 3.06e+15  |
# |    n_updates            | 100       |
# |    policy_gradient_loss | -2.76e-06 |
# |    reward               | 3105096.8 |
# |    std                  | 1         |
# |    value_loss           | 6.1e+15   |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:7590888.432216384
# Sharpe:  0.7583481212319124
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1026      |
# |    iterations           | 12        |
# |    time_elapsed         | 23        |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -38.3     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 4.44e+14  |
# |    n_updates            | 110       |
# |    policy_gradient_loss | -7.27e-06 |
# |    reward               | 1182536.0 |
# |    std                  | 1         |
# |    value_loss           | 8.97e+14  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1029      |
# |    iterations           | 13        |
# |    time_elapsed         | 25        |
# |    total_timesteps      | 26624     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -38.3     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 2.66e+15  |
# |    n_updates            | 120       |
# |    policy_gradient_loss | -2.69e-06 |
# |    reward               | 3370978.2 |
# |    std                  | 1         |
# |    value_loss           | 5.46e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:7867316.420877065
# Sharpe:  0.7624976336517643
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1027      |
# |    iterations           | 14        |
# |    time_elapsed         | 27        |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -38.3     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 5.43e+14  |
# |    n_updates            | 130       |
# |    policy_gradient_loss | -7.25e-06 |
# |    reward               | 1263747.5 |
# |    std                  | 1         |
# |    value_loss           | 1.15e+15  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1032      |
# |    iterations           | 15        |
# |    time_elapsed         | 29        |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -38.3     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 3.12e+15  |
# |    n_updates            | 140       |
# |    policy_gradient_loss | -2.78e-06 |
# |    reward               | 3403271.0 |
# |    std                  | 1         |
# |    value_loss           | 5.84e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:7474970.296385816
# Sharpe:  0.7503591596040194
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1029      |
# |    iterations           | 16        |
# |    time_elapsed         | 31        |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -38.3     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 5.74e+14  |
# |    n_updates            | 150       |
# |    policy_gradient_loss | -6.39e-06 |
# |    reward               | 1249845.9 |
# |    std                  | 1         |
# |    value_loss           | 1.09e+15  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1034      |
# |    iterations           | 17        |
# |    time_elapsed         | 33        |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -38.3     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | 2.69e+15  |
# |    n_updates            | 160       |
# |    policy_gradient_loss | -2.73e-06 |
# |    reward               | 3306402.0 |
# |    std                  | 1         |
# |    value_loss           | 5.62e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:7455762.625583888
# Sharpe:  0.7505121339303666
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1027      |
# |    iterations           | 18        |
# |    time_elapsed         | 35        |
# |    total_timesteps      | 36864     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -38.3     |
# |    explained_variance   | -2.38e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | 5.2e+14   |
# |    n_updates            | 170       |
# |    policy_gradient_loss | -5.74e-06 |
# |    reward               | 1444165.8 |
# |    std                  | 1         |
# |    value_loss           | 1.07e+15  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1030      |
# |    iterations           | 19        |
# |    time_elapsed         | 37        |
# |    total_timesteps      | 38912     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -38.3     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 2.45e+15  |
# |    n_updates            | 180       |
# |    policy_gradient_loss | -3.2e-06  |
# |    reward               | 3611020.5 |
# |    std                  | 1         |
# |    value_loss           | 4.93e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:7649818.017723064
# Sharpe:  0.7568796290295298
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1028      |
# |    iterations           | 20        |
# |    time_elapsed         | 39        |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -38.3     |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.001     |
# |    loss                 | 6.86e+14  |
# |    n_updates            | 190       |
# |    policy_gradient_loss | -5.21e-06 |
# |    reward               | 1378793.1 |
# |    std                  | 1         |
# |    value_loss           | 1.34e+15  |
# ---------------------------------------

# %%
trained_ppo.save("ppo_dow30_2004_2021")

# %%
model = get_model("a2c", agent)
# Out:
# {'n_steps': 10, 'ent_coef': 0.005, 'learning_rate': 0.0004}
# Using cpu device

# %%
trained_a2c = agent.train_model(model=model, tb_log_name="a2c", total_timesteps=40000)
# Out:
# -------------------------------------
# | time/                 |           |
# |    fps                | 864       |
# |    iterations         | 100       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -38.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 99        |
# |    policy_loss        | 2.07e+08  |
# |    reward             | 1051628.5 |
# |    std                | 0.998     |
# |    value_loss         | 3.82e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 914       |
# |    iterations         | 200       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -38.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 199       |
# |    policy_loss        | 4.55e+08  |
# |    reward             | 2260201.5 |
# |    std                | 0.996     |
# |    value_loss         | 1.73e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 936       |
# |    iterations         | 300       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -38.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 299       |
# |    policy_loss        | 8.28e+08  |
# |    reward             | 4167477.0 |
# |    std                | 0.996     |
# |    value_loss         | 6.07e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 935       |
# |    iterations         | 400       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -38.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 399       |
# |    policy_loss        | 1.53e+09  |
# |    reward             | 7657056.0 |
# |    std                | 0.994     |
# |    value_loss         | 1.83e+15  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:8146030.200247951
# Sharpe:  0.7800320668732201
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 916       |
# |    iterations         | 500       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -38.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 499       |
# |    policy_loss        | 2.22e+08  |
# |    reward             | 1073873.4 |
# |    std                | 0.994     |
# |    value_loss         | 4.25e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 917       |
# |    iterations         | 600       |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -38.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 599       |
# |    policy_loss        | 5.05e+08  |
# |    reward             | 2428986.2 |
# |    std                | 0.992     |
# |    value_loss         | 2.16e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 923       |
# |    iterations         | 700       |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -38.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 699       |
# |    policy_loss        | 8.71e+08  |
# |    reward             | 4252061.0 |
# |    std                | 0.993     |
# |    value_loss         | 6.55e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 929       |
# |    iterations         | 800       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -38.1     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 799       |
# |    policy_loss        | 1.48e+09  |
# |    reward             | 7846532.5 |
# |    std                | 0.992     |
# |    value_loss         | 2.01e+15  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:8749330.505792603
# Sharpe:  0.7998517194261792
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 924       |
# |    iterations         | 900       |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -38.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 899       |
# |    policy_loss        | 2.74e+08  |
# |    reward             | 1217803.5 |
# |    std                | 0.991     |
# |    value_loss         | 6.19e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 924       |
# |    iterations         | 1000      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -38       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 999       |
# |    policy_loss        | 4.06e+08  |
# |    reward             | 2140766.5 |
# |    std                | 0.99      |
# |    value_loss         | 1.56e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 925       |
# |    iterations         | 1100      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -38       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1099      |
# |    policy_loss        | 8.06e+08  |
# |    reward             | 3805670.2 |
# |    std                | 0.989     |
# |    value_loss         | 5.41e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 929       |
# |    iterations         | 1200      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -38       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1199      |
# |    policy_loss        | 1.41e+09  |
# |    reward             | 6816552.5 |
# |    std                | 0.989     |
# |    value_loss         | 1.54e+15  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:7438356.233159459
# Sharpe:  0.7520215742814094
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 923       |
# |    iterations         | 1300      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -38       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1299      |
# |    policy_loss        | 2.97e+08  |
# |    reward             | 1421290.1 |
# |    std                | 0.989     |
# |    value_loss         | 6.91e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 924       |
# |    iterations         | 1400      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -38       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1399      |
# |    policy_loss        | 4.76e+08  |
# |    reward             | 2257903.0 |
# |    std                | 0.989     |
# |    value_loss         | 1.69e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 925       |
# |    iterations         | 1500      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -38       |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1499      |
# |    policy_loss        | 7.96e+08  |
# |    reward             | 3989489.5 |
# |    std                | 0.988     |
# |    value_loss         | 5.7e+14   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 928       |
# |    iterations         | 1600      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -38       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1599      |
# |    policy_loss        | 1.3e+09   |
# |    reward             | 6593304.0 |
# |    std                | 0.988     |
# |    value_loss         | 1.49e+15  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:7735919.824962
# Sharpe:  0.7626579212202641
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 921       |
# |    iterations         | 1700      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -38       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1699      |
# |    policy_loss        | 2.67e+08  |
# |    reward             | 1256568.1 |
# |    std                | 0.987     |
# |    value_loss         | 6.31e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 923       |
# |    iterations         | 1800      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -37.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1799      |
# |    policy_loss        | 3.97e+08  |
# |    reward             | 2035168.9 |
# |    std                | 0.987     |
# |    value_loss         | 1.42e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 924       |
# |    iterations         | 1900      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -37.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1899      |
# |    policy_loss        | 7.48e+08  |
# |    reward             | 3606498.0 |
# |    std                | 0.987     |
# |    value_loss         | 4.59e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 924       |
# |    iterations         | 2000      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -38       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1999      |
# |    policy_loss        | 1.15e+09  |
# |    reward             | 5999758.0 |
# |    std                | 0.987     |
# |    value_loss         | 1.25e+15  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:7254549.561005128
# Sharpe:  0.7426691296445361
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 918       |
# |    iterations         | 2100      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -37.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2099      |
# |    policy_loss        | 2.92e+08  |
# |    reward             | 1405213.5 |
# |    std                | 0.986     |
# |    value_loss         | 7.39e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 919       |
# |    iterations         | 2200      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -37.9     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2199      |
# |    policy_loss        | 4.46e+08  |
# |    reward             | 2074766.1 |
# |    std                | 0.986     |
# |    value_loss         | 1.71e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 919       |
# |    iterations         | 2300      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -37.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2299      |
# |    policy_loss        | 7.38e+08  |
# |    reward             | 3582775.8 |
# |    std                | 0.985     |
# |    value_loss         | 4.84e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 920       |
# |    iterations         | 2400      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -37.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2399      |
# |    policy_loss        | 1.25e+09  |
# |    reward             | 5543351.5 |
# |    std                | 0.984     |
# |    value_loss         | 1.12e+15  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:7188572.394282669
# Sharpe:  0.7396104735825286
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 917       |
# |    iterations         | 2500      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -37.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2499      |
# |    policy_loss        | 3.01e+08  |
# |    reward             | 1507005.0 |
# |    std                | 0.986     |
# |    value_loss         | 7.61e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 918       |
# |    iterations         | 2600      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -37.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2599      |
# |    policy_loss        | 5e+08     |
# |    reward             | 2385268.2 |
# |    std                | 0.986     |
# |    value_loss         | 2.05e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 918       |
# |    iterations         | 2700      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -37.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2699      |
# |    policy_loss        | 8.06e+08  |
# |    reward             | 4142603.5 |
# |    std                | 0.985     |
# |    value_loss         | 5.94e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 919       |
# |    iterations         | 2800      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -37.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2799      |
# |    policy_loss        | 1.37e+09  |
# |    reward             | 5826935.5 |
# |    std                | 0.985     |
# |    value_loss         | 1.57e+15  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:8676517.225769648
# Sharpe:  0.8010779437085714
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 917       |
# |    iterations         | 2900      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -37.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2899      |
# |    policy_loss        | 2.84e+08  |
# |    reward             | 1305586.8 |
# |    std                | 0.985     |
# |    value_loss         | 6.67e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 919       |
# |    iterations         | 3000      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -37.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2999      |
# |    policy_loss        | 4.37e+08  |
# |    reward             | 2127175.5 |
# |    std                | 0.985     |
# |    value_loss         | 1.56e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 919       |
# |    iterations         | 3100      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -37.9     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3099      |
# |    policy_loss        | 6.59e+08  |
# |    reward             | 3554344.2 |
# |    std                | 0.984     |
# |    value_loss         | 4.36e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 920       |
# |    iterations         | 3200      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -37.8     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3199      |
# |    policy_loss        | 1.44e+09  |
# |    reward             | 7174475.0 |
# |    std                | 0.983     |
# |    value_loss         | 1.8e+15   |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:7798077.1583928
# Sharpe:  0.7680007744207702
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 918       |
# |    iterations         | 3300      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -37.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3299      |
# |    policy_loss        | 3.12e+08  |
# |    reward             | 1392902.9 |
# |    std                | 0.984     |
# |    value_loss         | 7.05e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 918       |
# |    iterations         | 3400      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -37.8     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3399      |
# |    policy_loss        | 3.54e+08  |
# |    reward             | 1962414.8 |
# |    std                | 0.982     |
# |    value_loss         | 1.27e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 919       |
# |    iterations         | 3500      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -37.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3499      |
# |    policy_loss        | 7.27e+08  |
# |    reward             | 3217235.2 |
# |    std                | 0.983     |
# |    value_loss         | 4.32e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 919       |
# |    iterations         | 3600      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -37.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3599      |
# |    policy_loss        | 1.26e+09  |
# |    reward             | 6572915.0 |
# |    std                | 0.982     |
# |    value_loss         | 1.49e+15  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:7317746.221394614
# Sharpe:  0.747103326059669
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 918       |
# |    iterations         | 3700      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -37.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3699      |
# |    policy_loss        | 3.09e+08  |
# |    reward             | 1547989.9 |
# |    std                | 0.981     |
# |    value_loss         | 8.6e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 918       |
# |    iterations         | 3800      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -37.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3799      |
# |    policy_loss        | 3.66e+08  |
# |    reward             | 1819304.8 |
# |    std                | 0.982     |
# |    value_loss         | 1.07e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 920       |
# |    iterations         | 3900      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -37.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3899      |
# |    policy_loss        | 7.13e+08  |
# |    reward             | 3560051.2 |
# |    std                | 0.981     |
# |    value_loss         | 4.4e+14   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 921       |
# |    iterations         | 4000      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -37.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3999      |
# |    policy_loss        | 1.24e+09  |
# |    reward             | 6436135.0 |
# |    std                | 0.98      |
# |    value_loss         | 1.44e+15  |
# -------------------------------------

# %%
trained_a2c.save("a2c_dow30_2004_2021")

# %%
df_daily_return_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
    model=trained_a2c, environment=env
)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:8187789.915619479
# Sharpe:  0.7830369430486934
# =================================
# hit end!

# %%
from utils import convert_daily_return_to_pyfolio_ts, extract_weights

# %%
import plotly.graph_objs as go

# %%
def prediction_plot(models, env):
    traces = []
    for model in models:
        df_daily_return, df_actions = DRLAgent.DRL_prediction(model=model, environment=env)
        df_cumprod = (df_daily_return.daily_return + 1).cumprod() - 1
        time_ind = pd.Series(df_daily_return.date)
        trace_portfolio = go.Scatter(x=time_ind, y=df_cumprod, mode="lines", name=model.__class__.__name__)
        traces.append(trace_portfolio)

    fig = go.Figure()
    for trace in traces:
        fig.add_trace(trace)
    fig.update_layout(
        legend=dict(
            x=0,
            y=1,
            traceorder="normal",
            font=dict(family="sans-serif", size=15, color="black"),
            bgcolor="White",
            bordercolor="white",
            borderwidth=2,
        ),
    )
    fig.update_layout(
        title={
            #'text': "Cumulative Return using FinRL",
            "y": 0.85,
            "x": 0.5,
            "xanchor": "center",
            "yanchor": "top",
        }
    )

    fig.update_layout(
        paper_bgcolor="rgba(1,1,0,0)",
        plot_bgcolor="rgba(1, 1, 0, 0)",
        xaxis_title="Date",
        yaxis=dict(titlefont=dict(size=30), title="Cumulative Return"),
        font=dict(
            size=40,
        ),
    )
    fig.update_layout(font_size=20)
    fig.update_traces(line=dict(width=2))

    fig.update_xaxes(
        showline=True,
        linecolor="black",
        showgrid=True,
        gridwidth=1,
        gridcolor="LightSteelBlue",
        mirror=True,
    )
    fig.update_yaxes(
        showline=True,
        linecolor="black",
        showgrid=True,
        gridwidth=1,
        gridcolor="LightSteelBlue",
        mirror=True,
    )
    fig.update_yaxes(zeroline=True, zerolinewidth=1, zerolinecolor="LightSteelBlue")
    return fig

# %%
prediction_plot([trained_ppo, trained_a2c], env)
# Out:
# /Users/vsaravind/dev/rl_final_lab/portfolio_manager/.venv/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning:
#
# You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
# =================================
# begin_total_asset:1000000
# end_total_asset:7608292.692738084
# Sharpe:  0.75865048405573
# =================================
# hit end!
# /Users/vsaravind/dev/rl_final_lab/portfolio_manager/.venv/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning:
#
# You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
# =================================
# begin_total_asset:1000000
# end_total_asset:8187789.915619479
# Sharpe:  0.7830369430486934
# =================================
# hit end!
