# %%
from finrl import config
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer

# %%
from utils import data_split, convert_daily_return_to_pyfolio_ts, extract_weights

# %%
import pandas as pd
import numpy as np

# %%
import os
from finrl import config
from finrl import config_tickers

if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %%
from settings import DOW_30_TICKER, PPO_PARAMS

# %%
from data_loader import Yahoo_Downloader

df = Yahoo_Downloader(start_date = '2008-01-01',
                     end_date = '2021-09-02',
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (100385, 8)

# %%
df.head()
# Out:
#          date       open       high        low      close      volume   tic  \
# 0  2008-01-02   7.116786   7.152143   6.876786   5.891120  1079178800  AAPL
# 1  2008-01-02  46.599998  47.040001  46.259998  33.499519     7934400  AMGN
# 2  2008-01-02  52.090000  52.320000  50.790001  39.338642     8053700   AXP
# 3  2008-01-02  87.570000  87.839996  86.000000  63.481625     4303000    BA
# 4  2008-01-02  72.559998  72.669998  70.050003  45.395149     6337800   CAT
#
#    day
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2

# %%
fe = FeatureEngineer(use_technical_indicator=True, use_turbulence=False, user_defined_feature=False)

df = fe.preprocess_data(df)
# Out:
# Successfully added technical indicators

# %%
df.head()
# Out:
#              date       open       high        low      close      volume  \
# 0      2008-01-02   7.116786   7.152143   6.876786   5.891120  1079178800
# 3442   2008-01-02  46.599998  47.040001  46.259998  33.499519     7934400
# 6884   2008-01-02  52.090000  52.320000  50.790001  39.338642     8053700
# 10326  2008-01-02  87.570000  87.839996  86.000000  63.481625     4303000
# 13768  2008-01-02  72.559998  72.669998  70.050003  45.395149     6337800
#
#         tic  day  macd   boll_ub   boll_lb  rsi_30     cci_30  dx_30  \
# 0      AAPL    2   0.0  5.896337  5.888629   100.0 -66.666667  100.0
# 3442   AMGN    2   0.0  5.896337  5.888629   100.0 -66.666667  100.0
# 6884    AXP    2   0.0  5.896337  5.888629   100.0 -66.666667  100.0
# 10326    BA    2   0.0  5.896337  5.888629   100.0 -66.666667  100.0
# 13768   CAT    2   0.0  5.896337  5.888629   100.0 -66.666667  100.0
#
#        close_30_sma  close_60_sma
# 0          5.891120      5.891120
# 3442      33.499519     33.499519
# 6884      39.338642     39.338642
# 10326     63.481625     63.481625
# 13768     45.395149     45.395149

# %%
# add covariance matrix as states
df = df.sort_values(["date", "tic"], ignore_index=True)
df.index = df.date.factorize()[0]

cov_list = []
return_list = []

# look back is one year
lookback = 252
for i in range(lookback, len(df.index.unique())):
    data_lookback = df.loc[i - lookback : i, :]
    price_lookback = data_lookback.pivot_table(index="date", columns="tic", values="close")
    return_lookback = price_lookback.pct_change().dropna()
    return_list.append(return_lookback)

    covs = return_lookback.cov().values
    cov_list.append(covs)


df_cov = pd.DataFrame(
    {"date": df.date.unique()[lookback:], "cov_list": cov_list, "return_list": return_list}
)
df = df.merge(df_cov, on="date")
df = df.sort_values(["date", "tic"]).reset_index(drop=True)

# %%
df.head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2008-12-31   3.070357   3.133571   3.047857   2.580616  607541200  AAPL
# 1  2008-12-31  57.110001  58.220001  57.060001  41.514980    6287200  AMGN
# 2  2008-12-31  17.969999  18.750000  17.910000  14.488909    9625600   AXP
# 3  2008-12-31  41.590000  43.049999  41.500000  32.005878    5443100    BA
# 4  2008-12-31  43.700001  45.099998  43.700001  29.472111    6277400   CAT
#
#    day      macd    boll_ub    boll_lb     rsi_30      cci_30      dx_30  \
# 0    2 -0.082498   3.089709   2.451164  42.254781  -80.459604  16.129793
# 1    2  0.155540  42.375760  40.536299  51.060615   51.513555  10.432018
# 2    2 -0.929690  18.529416  12.580723  42.554855  -75.453278  25.776759
# 3    2 -0.279800  32.174379  28.867839  47.440220  156.994500   5.366299
# 4    2  0.652586  30.208138  25.338258  51.205302   98.368728  26.331746
#
#    close_30_sma  close_60_sma  \
# 0      2.746056      2.858024
# 1     40.739552     40.288820
# 2     15.644893     17.505409
# 3     30.327214     32.389916
# 4     26.566471     26.301739
#
#                                             cov_list  \
# 0  [[0.001348969289176713, 0.00042841286661066716...
# 1  [[0.001348969289176713, 0.00042841286661066716...
# 2  [[0.001348969289176713, 0.00042841286661066716...
# 3  [[0.001348969289176713, 0.00042841286661066716...
# 4  [[0.001348969289176713, 0.00042841286661066716...
#
#                                          return_list
# 0  tic             AAPL      AMGN       AXP      ...
# 1  tic             AAPL      AMGN       AXP      ...
# 2  tic             AAPL      AMGN       AXP      ...
# 3  tic             AAPL      AMGN       AXP      ...
# 4  tic             AAPL      AMGN       AXP      ...

# %%
train = data_split(df, "2009-01-01", "2020-06-30")

# %%
stock_dimension = len(train.tic.unique())
state_space = stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
tech_indicator_list = ["macd", "rsi_30", "cci_30", "dx_30"]
feature_dimension = len(tech_indicator_list)
print(f"Feature Dimension: {feature_dimension}")
# Out:
# Stock Dimension: 28, State Space: 28
# Feature Dimension: 4

# %%
from env import StockPortfolioEnv

# %%
env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "transaction_cost_pct": 0,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": tech_indicator_list,
    "action_space": stock_dimension,
    "reward_scaling": 1e-1,
}

e_train_gym = StockPortfolioEnv(df=train, **env_kwargs)

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>
# /Users/vsaravind/dev/rl_final_lab/portfolio_manager/.venv/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
from drl_agent import DRLAgent

# %%
agent = DRLAgent(env=env_train)

A2C_PARAMS = {"n_steps": 10, "ent_coef": 0.005, "learning_rate": 0.0004}
model_a2c = agent.get_model(model_name="a2c", model_kwargs=A2C_PARAMS)
# Out:
# {'n_steps': 10, 'ent_coef': 0.005, 'learning_rate': 0.0004}
# Using cpu device

# %%
model_a2c

# %%
trained_a2c = agent.train_model(model=model_a2c, tb_log_name="a2c", total_timesteps=40000)
# Out:
# -------------------------------------
# | time/                 |           |
# |    fps                | 1061      |
# |    iterations         | 100       |
# |    time_elapsed       | 0         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 99        |
# |    policy_loss        | 4.27e+08  |
# |    reward             | 2143720.2 |
# |    std                | 0.996     |
# |    value_loss         | 1.6e+14   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1091      |
# |    iterations         | 200       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 199       |
# |    policy_loss        | 8.52e+08  |
# |    reward             | 4007871.8 |
# |    std                | 0.995     |
# |    value_loss         | 5.44e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6272422.547452465
# Sharpe:  0.9651292123191813
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 1048      |
# |    iterations         | 300       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 299       |
# |    policy_loss        | 2.13e+08  |
# |    reward             | 1066147.0 |
# |    std                | 0.995     |
# |    value_loss         | 3.69e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1062      |
# |    iterations         | 400       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 399       |
# |    policy_loss        | 4.87e+08  |
# |    reward             | 2332264.2 |
# |    std                | 0.994     |
# |    value_loss         | 1.89e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1085      |
# |    iterations         | 500       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 499       |
# |    policy_loss        | 8.86e+08  |
# |    reward             | 4184216.8 |
# |    std                | 0.993     |
# |    value_loss         | 6.46e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6357670.585863778
# Sharpe:  0.973085007107075
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 1077      |
# |    iterations         | 600       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 599       |
# |    policy_loss        | 2.76e+08  |
# |    reward             | 1325914.6 |
# |    std                | 0.992     |
# |    value_loss         | 5.97e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1087      |
# |    iterations         | 700       |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 699       |
# |    policy_loss        | 5.59e+08  |
# |    reward             | 2720166.0 |
# |    std                | 0.991     |
# |    value_loss         | 2.53e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1095      |
# |    iterations         | 800       |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 799       |
# |    policy_loss        | 9.53e+08  |
# |    reward             | 4813700.0 |
# |    std                | 0.991     |
# |    value_loss         | 7.93e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6135866.449891387
# Sharpe:  0.9536636497176298
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 1090      |
# |    iterations         | 900       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 899       |
# |    policy_loss        | 3.26e+08  |
# |    reward             | 1553226.1 |
# |    std                | 0.991     |
# |    value_loss         | 8.37e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1099      |
# |    iterations         | 1000      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 999       |
# |    policy_loss        | 6.12e+08  |
# |    reward             | 2819358.8 |
# |    std                | 0.99      |
# |    value_loss         | 2.86e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1103      |
# |    iterations         | 1100      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1099      |
# |    policy_loss        | 1.01e+09  |
# |    reward             | 4742783.0 |
# |    std                | 0.99      |
# |    value_loss         | 8.79e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5858816.868592534
# Sharpe:  0.9301566556795019
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 1096      |
# |    iterations         | 1200      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1199      |
# |    policy_loss        | 2.91e+08  |
# |    reward             | 1471138.1 |
# |    std                | 0.988     |
# |    value_loss         | 6.9e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1100      |
# |    iterations         | 1300      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1299      |
# |    policy_loss        | 5.89e+08  |
# |    reward             | 2896592.2 |
# |    std                | 0.987     |
# |    value_loss         | 2.95e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1104      |
# |    iterations         | 1400      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1399      |
# |    policy_loss        | 1.01e+09  |
# |    reward             | 4904721.5 |
# |    std                | 0.987     |
# |    value_loss         | 8.22e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5173770.587637283
# Sharpe:  0.876254806062086
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 1097      |
# |    iterations         | 1500      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1499      |
# |    policy_loss        | 3.78e+08  |
# |    reward             | 1752586.0 |
# |    std                | 0.987     |
# |    value_loss         | 1.13e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1099      |
# |    iterations         | 1600      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1599      |
# |    policy_loss        | 7.06e+08  |
# |    reward             | 3413761.8 |
# |    std                | 0.987     |
# |    value_loss         | 3.93e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1102      |
# |    iterations         | 1700      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1699      |
# |    policy_loss        | 1.13e+09  |
# |    reward             | 5827408.0 |
# |    std                | 0.986     |
# |    value_loss         | 1.14e+15  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6613345.044277274
# Sharpe:  0.9916833280377804
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 1096      |
# |    iterations         | 1800      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1799      |
# |    policy_loss        | 3.93e+08  |
# |    reward             | 1782877.1 |
# |    std                | 0.986     |
# |    value_loss         | 1.21e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1097      |
# |    iterations         | 1900      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1899      |
# |    policy_loss        | 7.24e+08  |
# |    reward             | 3646190.8 |
# |    std                | 0.986     |
# |    value_loss         | 4.63e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1100      |
# |    iterations         | 2000      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1999      |
# |    policy_loss        | 1.36e+09  |
# |    reward             | 6760607.0 |
# |    std                | 0.986     |
# |    value_loss         | 1.56e+15  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:7117072.861979049
# Sharpe:  1.0284202282400026
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 1095      |
# |    iterations         | 2100      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2099      |
# |    policy_loss        | 3.31e+08  |
# |    reward             | 1771875.5 |
# |    std                | 0.986     |
# |    value_loss         | 1.05e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1097      |
# |    iterations         | 2200      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2199      |
# |    policy_loss        | 6.87e+08  |
# |    reward             | 3287944.8 |
# |    std                | 0.987     |
# |    value_loss         | 3.87e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1099      |
# |    iterations         | 2300      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2299      |
# |    policy_loss        | 1.23e+09  |
# |    reward             | 5929299.5 |
# |    std                | 0.987     |
# |    value_loss         | 1.24e+15  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5679541.023579705
# Sharpe:  0.9262762843114212
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 1096      |
# |    iterations         | 2400      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2399      |
# |    policy_loss        | 4.14e+08  |
# |    reward             | 1928726.1 |
# |    std                | 0.986     |
# |    value_loss         | 1.35e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1097      |
# |    iterations         | 2500      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2499      |
# |    policy_loss        | 7.97e+08  |
# |    reward             | 3724799.0 |
# |    std                | 0.986     |
# |    value_loss         | 4.83e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1098      |
# |    iterations         | 2600      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2599      |
# |    policy_loss        | 1.28e+09  |
# |    reward             | 6053159.0 |
# |    std                | 0.987     |
# |    value_loss         | 1.27e+15  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6217189.043333711
# Sharpe:  0.9690179555406297
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 1091      |
# |    iterations         | 2700      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2699      |
# |    policy_loss        | 4.31e+08  |
# |    reward             | 1940594.1 |
# |    std                | 0.986     |
# |    value_loss         | 1.47e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1094      |
# |    iterations         | 2800      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2799      |
# |    policy_loss        | 7.73e+08  |
# |    reward             | 3556889.0 |
# |    std                | 0.985     |
# |    value_loss         | 4.66e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6093014.424099928
# Sharpe:  0.9601453289620476
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 1091       |
# |    iterations         | 2900       |
# |    time_elapsed       | 26         |
# |    total_timesteps    | 29000      |
# | train/                |            |
# |    entropy_loss       | -39.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0004     |
# |    n_updates          | 2899       |
# |    policy_loss        | 2.15e+08   |
# |    reward             | 1021045.44 |
# |    std                | 0.985      |
# |    value_loss         | 3.43e+13   |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1093      |
# |    iterations         | 3000      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2999      |
# |    policy_loss        | 4.99e+08  |
# |    reward             | 2401795.5 |
# |    std                | 0.984     |
# |    value_loss         | 2.04e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1094      |
# |    iterations         | 3100      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3099      |
# |    policy_loss        | 9.59e+08  |
# |    reward             | 4292351.0 |
# |    std                | 0.984     |
# |    value_loss         | 6.68e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6199175.568140278
# Sharpe:  0.9665895057841513
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 1092      |
# |    iterations         | 3200      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3199      |
# |    policy_loss        | 2.53e+08  |
# |    reward             | 1244601.6 |
# |    std                | 0.983     |
# |    value_loss         | 5.69e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1093      |
# |    iterations         | 3300      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3299      |
# |    policy_loss        | 5.04e+08  |
# |    reward             | 2552954.8 |
# |    std                | 0.981     |
# |    value_loss         | 2.15e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1095      |
# |    iterations         | 3400      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3399      |
# |    policy_loss        | 9.68e+08  |
# |    reward             | 4510181.5 |
# |    std                | 0.982     |
# |    value_loss         | 7.04e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6048917.920339534
# Sharpe:  0.951488166196599
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 1094      |
# |    iterations         | 3500      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3499      |
# |    policy_loss        | 2.75e+08  |
# |    reward             | 1398017.0 |
# |    std                | 0.981     |
# |    value_loss         | 6.45e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1096      |
# |    iterations         | 3600      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3599      |
# |    policy_loss        | 5.43e+08  |
# |    reward             | 2829374.8 |
# |    std                | 0.98      |
# |    value_loss         | 2.66e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1098      |
# |    iterations         | 3700      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3699      |
# |    policy_loss        | 1.11e+09  |
# |    reward             | 5222980.5 |
# |    std                | 0.981     |
# |    value_loss         | 1.09e+15  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6285100.490418724
# Sharpe:  0.9682517044724094
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 1097      |
# |    iterations         | 3800      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3799      |
# |    policy_loss        | 2.81e+08  |
# |    reward             | 1352946.2 |
# |    std                | 0.981     |
# |    value_loss         | 6.6e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1098      |
# |    iterations         | 3900      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3899      |
# |    policy_loss        | 5.9e+08   |
# |    reward             | 2941746.8 |
# |    std                | 0.981     |
# |    value_loss         | 3.22e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1099      |
# |    iterations         | 4000      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3999      |
# |    policy_loss        | 1.1e+09   |
# |    reward             | 5155825.5 |
# |    std                | 0.98      |
# |    value_loss         | 9e+14     |
# -------------------------------------

# %%
agent = DRLAgent(env=env_train)

model_ppo = agent.get_model("ppo", model_kwargs=PPO_PARAMS)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.005, 'learning_rate': 0.001, 'batch_size': 128}
# Using cpu device

# %%
trained_ppo = agent.train_model(model=model_ppo, tb_log_name="ppo", total_timesteps=40000)
# Out:
# ----------------------------------
# | time/              |           |
# |    fps             | 1485      |
# |    iterations      | 1         |
# |    time_elapsed    | 1         |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 4084083.8 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6059117.57936095
# Sharpe:  0.9514065572742054
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1307      |
# |    iterations           | 2         |
# |    time_elapsed         | 3         |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 8.1e+14   |
# |    n_updates            | 10        |
# |    policy_gradient_loss | -5.86e-06 |
# |    reward               | 2506186.2 |
# |    std                  | 1         |
# |    value_loss           | 1.74e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5687342.264489334
# Sharpe:  0.915797835939362
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1263      |
# |    iterations           | 3         |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.85e+15  |
# |    n_updates            | 20        |
# |    policy_gradient_loss | -3.86e-06 |
# |    reward               | 1373836.5 |
# |    std                  | 1         |
# |    value_loss           | 3.61e+15  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1259      |
# |    iterations           | 4         |
# |    time_elapsed         | 6         |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 2.03e+15  |
# |    n_updates            | 30        |
# |    policy_gradient_loss | -3.97e-06 |
# |    reward               | 5493486.0 |
# |    std                  | 1         |
# |    value_loss           | 4.25e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6193586.216382457
# Sharpe:  0.957510029569341
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1244      |
# |    iterations           | 5         |
# |    time_elapsed         | 8         |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.6e+15   |
# |    n_updates            | 40        |
# |    policy_gradient_loss | -3.77e-06 |
# |    reward               | 3163676.2 |
# |    std                  | 1         |
# |    value_loss           | 3.04e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5695746.005020453
# Sharpe:  0.9163800232218767
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1235      |
# |    iterations           | 6         |
# |    time_elapsed         | 9         |
# |    total_timesteps      | 12288     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.45e+15  |
# |    n_updates            | 50        |
# |    policy_gradient_loss | -4.26e-06 |
# |    reward               | 1700586.4 |
# |    std                  | 1         |
# |    value_loss           | 3.12e+15  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1237      |
# |    iterations           | 7         |
# |    time_elapsed         | 11        |
# |    total_timesteps      | 14336     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.87e+15  |
# |    n_updates            | 60        |
# |    policy_gradient_loss | -3.17e-06 |
# |    reward               | 6678312.0 |
# |    std                  | 1         |
# |    value_loss           | 3.79e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6111781.555020613
# Sharpe:  0.9520359751657815
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1233      |
# |    iterations           | 8         |
# |    time_elapsed         | 13        |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 2e+15     |
# |    n_updates            | 70        |
# |    policy_gradient_loss | -3.52e-06 |
# |    reward               | 3616580.8 |
# |    std                  | 1         |
# |    value_loss           | 4.34e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5963376.303167841
# Sharpe:  0.9371343262667443
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1228      |
# |    iterations           | 9         |
# |    time_elapsed         | 15        |
# |    total_timesteps      | 18432     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.16e+15  |
# |    n_updates            | 80        |
# |    policy_gradient_loss | -5.72e-06 |
# |    reward               | 2376536.5 |
# |    std                  | 1         |
# |    value_loss           | 1.94e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5998383.214585563
# Sharpe:  0.9456940109397631
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1225      |
# |    iterations           | 10        |
# |    time_elapsed         | 16        |
# |    total_timesteps      | 20480     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | 2.16e+15  |
# |    n_updates            | 90        |
# |    policy_gradient_loss | -3.69e-06 |
# |    reward               | 1313416.6 |
# |    std                  | 1         |
# |    value_loss           | 3.82e+15  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1228      |
# |    iterations           | 11        |
# |    time_elapsed         | 18        |
# |    total_timesteps      | 22528     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.001     |
# |    loss                 | 2.11e+15  |
# |    n_updates            | 100       |
# |    policy_gradient_loss | -3.39e-06 |
# |    reward               | 5114349.5 |
# |    std                  | 1         |
# |    value_loss           | 4.49e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5578219.9515871825
# Sharpe:  0.9115422328181281
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1220      |
# |    iterations           | 12        |
# |    time_elapsed         | 20        |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.1e+15   |
# |    n_updates            | 110       |
# |    policy_gradient_loss | -4.8e-06  |
# |    reward               | 3014763.8 |
# |    std                  | 1         |
# |    value_loss           | 2.18e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5559682.488420657
# Sharpe:  0.9088199540463459
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1219      |
# |    iterations           | 13        |
# |    time_elapsed         | 21        |
# |    total_timesteps      | 26624     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.22e+15  |
# |    n_updates            | 120       |
# |    policy_gradient_loss | -3.98e-06 |
# |    reward               | 1691214.2 |
# |    std                  | 1         |
# |    value_loss           | 3.02e+15  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1224      |
# |    iterations           | 14        |
# |    time_elapsed         | 23        |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.85e+15  |
# |    n_updates            | 130       |
# |    policy_gradient_loss | -3.24e-06 |
# |    reward               | 5521682.0 |
# |    std                  | 1         |
# |    value_loss           | 3.81e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5595257.82989583
# Sharpe:  0.909931521694687
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1222      |
# |    iterations           | 15        |
# |    time_elapsed         | 25        |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.55e+15  |
# |    n_updates            | 140       |
# |    policy_gradient_loss | -3.7e-06  |
# |    reward               | 3268331.8 |
# |    std                  | 1         |
# |    value_loss           | 3.17e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6004944.145824379
# Sharpe:  0.9447996680370114
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1222      |
# |    iterations           | 16        |
# |    time_elapsed         | 26        |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.17e+15  |
# |    n_updates            | 150       |
# |    policy_gradient_loss | -5.22e-06 |
# |    reward               | 2095658.4 |
# |    std                  | 1         |
# |    value_loss           | 2.28e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6004164.107239267
# Sharpe:  0.9450825842832326
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1222      |
# |    iterations           | 17        |
# |    time_elapsed         | 28        |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | -2.38e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | 2.04e+15  |
# |    n_updates            | 160       |
# |    policy_gradient_loss | -3.76e-06 |
# |    reward               | 1047107.1 |
# |    std                  | 1         |
# |    value_loss           | 4.02e+15  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1226      |
# |    iterations           | 18        |
# |    time_elapsed         | 30        |
# |    total_timesteps      | 36864     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.001     |
# |    loss                 | 2.66e+15  |
# |    n_updates            | 170       |
# |    policy_gradient_loss | -3.13e-06 |
# |    reward               | 4334133.5 |
# |    std                  | 1         |
# |    value_loss           | 4.94e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6124122.693607519
# Sharpe:  0.9561848173067337
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1225      |
# |    iterations           | 19        |
# |    time_elapsed         | 31        |
# |    total_timesteps      | 38912     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 9.31e+14  |
# |    n_updates            | 180       |
# |    policy_gradient_loss | -4.19e-06 |
# |    reward               | 2909215.8 |
# |    std                  | 1         |
# |    value_loss           | 1.89e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6332878.688217488
# Sharpe:  0.9718530505640264
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1225      |
# |    iterations           | 20        |
# |    time_elapsed         | 33        |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -39.7     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.69e+15  |
# |    n_updates            | 190       |
# |    policy_gradient_loss | -4.5e-06  |
# |    reward               | 1538316.4 |
# |    std                  | 1         |
# |    value_loss           | 3.54e+15  |
# ---------------------------------------

# %%
trade = data_split(df, "2020-07-01", "2021-09-02")
e_trade_gym = StockPortfolioEnv(df=trade, **env_kwargs)

# %%
import torch
# %matplotlib inline
import plotly.express as px

# %%
from pyfolio import timeseries

df_daily_return_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
    model=trained_a2c, environment=e_trade_gym
)
df_daily_return_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
    model=trained_ppo, environment=e_trade_gym
)
# Out:
# /Users/vsaravind/dev/rl_final_lab/portfolio_manager/.venv/lib/python3.10/site-packages/pyfolio/pos.py:26: UserWarning:
#
# Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#
# /Users/vsaravind/dev/rl_final_lab/portfolio_manager/.venv/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning:
#
# You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
# =================================
# begin_total_asset:1000000
# end_total_asset:1390478.3706971814
# Sharpe:  2.128375461658797
# =================================
# hit end!
# =================================
# begin_total_asset:1000000
# end_total_asset:1409504.518459843
# Sharpe:  2.1808144476832703
# =================================
# hit end!
# /Users/vsaravind/dev/rl_final_lab/portfolio_manager/.venv/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning:
#
# You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.

# %%
trained_ppo.save("trained_ppo")

# %%
model = agent.get_model("ppo", model_kwargs=PPO_PARAMS)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.005, 'learning_rate': 0.001, 'batch_size': 128}
# Using cpu device

# %%
model.load("trained_ppo")

# %%
df_daily_return_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
    model=model, environment=e_trade_gym
)
# Out:
# /Users/vsaravind/dev/rl_final_lab/portfolio_manager/.venv/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning:
#
# You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
# =================================
# begin_total_asset:1000000
# end_total_asset:1409325.1891910199
# Sharpe:  2.180276058026452
# =================================
# hit end!

# %%
time_ind = pd.Series(df_daily_return_a2c.date)
a2c_cumpod = (df_daily_return_a2c.daily_return + 1).cumprod() - 1
ppo_cumpod = (df_daily_return_ppo.daily_return + 1).cumprod() - 1
DRL_strat_a2c = convert_daily_return_to_pyfolio_ts(df_daily_return_a2c)
DRL_strat_ppo = convert_daily_return_to_pyfolio_ts(df_daily_return_ppo)

# %%
perf_func = timeseries.perf_stats
perf_stats_all_a2c = perf_func(
    returns=DRL_strat_a2c,
    factor_returns=DRL_strat_a2c,
    positions=None,
    transactions=None,
    turnover_denom="AGB",
)
perf_stats_all_ppo = perf_func(
    returns=DRL_strat_ppo,
    factor_returns=DRL_strat_ppo,
    positions=None,
    transactions=None,
    turnover_denom="AGB",
)

# %%
from utils import extract_weights

# %%
a2c_weights = extract_weights(df_actions_a2c)
ppo_weights = extract_weights(df_actions_ppo)

# %%
baseline_df = Yahoo_Downloader(ticker_list=['^DJI'], start_date='2020-07-01', end_date='2021-09-02').fetch_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (296, 8)

# %%
from finrl.plot import backtest_stats, get_daily_return

# %%
baseline_df_stats = backtest_stats(baseline_df, value_col_name="close")
baseline_returns = get_daily_return(baseline_df, value_col_name="close")
# Out:
# Annual return          0.309122
# Cumulative returns     0.372161
# Annual volatility      0.140541
# Sharpe ratio           1.994221
# Calmar ratio           3.461310
# Stability              0.950010
# Max drawdown          -0.089308
# Omega ratio            1.394724
# Sortino ratio          2.971027
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.095028
# Daily value at risk   -0.016594
# dtype: float64

# %%
dji_cumpod = (baseline_returns + 1).cumprod() - 1

# %%
dji_cumpod
# Out:
# date
# 2020-07-01 00:00:00+00:00         NaN
# 2020-07-02 00:00:00+00:00    0.003590
# 2020-07-06 00:00:00+00:00    0.021452
# 2020-07-07 00:00:00+00:00    0.006031
# 2020-07-08 00:00:00+00:00    0.012913
#                                ...
# 2021-08-26 00:00:00+00:00    0.368298
# 2021-08-27 00:00:00+00:00    0.377728
# 2021-08-30 00:00:00+00:00    0.375554
# 2021-08-31 00:00:00+00:00    0.374034
# 2021-09-01 00:00:00+00:00    0.372161
# Name: daily_return, Length: 296, dtype: float64

# %%
from datetime import datetime as dt

import matplotlib.pyplot as plt
import plotly
import plotly.graph_objs as go

trace1_portfolio = go.Scatter(x=time_ind, y=a2c_cumpod, mode="lines", name="A2C")
trace2_portfolio = go.Scatter(x=time_ind, y=ppo_cumpod, mode="lines", name="PPO")
trace3_portfolio = go.Scatter(x=time_ind, y=dji_cumpod, mode="lines", name="DJIA")

# %%
fig = go.Figure()
fig.add_trace(trace1_portfolio)
fig.add_trace(trace2_portfolio)

fig.add_trace(trace3_portfolio)

fig.update_layout(
    legend=dict(
        x=0,
        y=1,
        traceorder="normal",
        font=dict(family="sans-serif", size=15, color="black"),
        bgcolor="White",
        bordercolor="white",
        borderwidth=2,
    ),
)
fig.update_layout(
    title={
        #'text': "Cumulative Return using FinRL",
        "y": 0.85,
        "x": 0.5,
        "xanchor": "center",
        "yanchor": "top",
    }
)

fig.update_layout(
    paper_bgcolor="rgba(1,1,0,0)",
    plot_bgcolor="rgba(1, 1, 0, 0)",
    xaxis_title="Date",
    yaxis=dict(titlefont=dict(size=30), title="Cumulative Return"),
    font=dict(
        size=40,
    ),
)
fig.update_layout(font_size=20)
fig.update_traces(line=dict(width=2))

fig.update_xaxes(
    showline=True,
    linecolor="black",
    showgrid=True,
    gridwidth=1,
    gridcolor="LightSteelBlue",
    mirror=True,
)
fig.update_yaxes(
    showline=True,
    linecolor="black",
    showgrid=True,
    gridwidth=1,
    gridcolor="LightSteelBlue",
    mirror=True,
)
fig.update_yaxes(zeroline=True, zerolinewidth=1, zerolinecolor="LightSteelBlue")

fig.show()
